# %%
def solution(n):
    answer = 0
    a = []
    while True:
        if n<3:
            a.append(n)
            break
        a.append(n % 3)
        n = n // 3

    
    a = a[::-1]
    for i in range(len(a)):
        answer += a[i]*(3**i)
    return answer
