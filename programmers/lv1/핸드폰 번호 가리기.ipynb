# %%
def solution(phone_number):
    answer = ''
    a = len(phone_number)-4
    b = list(str(phone_number))
    for i in range(len(phone_number)):
        if i < a:
            answer += '*'
        else:
            answer += b[i]
    return answer
