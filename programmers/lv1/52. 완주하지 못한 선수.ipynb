# %%
def solution(par, com):

    par.sort()
    com.sort()
    
    for i in range(len(com)):
        if(par[i] != com[i]):
            return par[i]
        
    return par[-1]

# %%
solution(["leo", "kiki", "eden"], ["eden", "kiki"])
# Out:
# 'leo'
