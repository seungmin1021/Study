# %%
from itertools import combinations as c
def solution(nums):
    answer = 0
    num = [sum(i) for i in c(nums,3)]
    for i in num:
        for j in range(3,i):
            if i % j == 0:
                break
        else:
            answer += 1
    return answer
