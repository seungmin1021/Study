# %%
def solution(n):
    import math
    answer = 0
    if math.sqrt(n) == int(math.sqrt(n)):
        answer = (math.sqrt(n) + 1) * (math.sqrt(n) + 1)
    else:
        answer = -1

    return answer
