# %%
def solution(a, b):
    month  = ['0','31','29','31','30','31','30','31','31','30','31','30']
    day = ['THU','FRI','SAT','SUN','MON','TUE','WED']
    cnt = 0
    for i in range(a):
        cnt += int(month[i])
    cnt += b
    return day[cnt % 7]

# %%
solution(5,24)
# Out:
# 'TUE'
