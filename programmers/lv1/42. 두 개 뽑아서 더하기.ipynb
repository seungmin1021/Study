# %%
from itertools import combinations as c
def solution(numbers):
    answer = []
    for j in c(numbers,2):
        answer.append(sum(j))
    
    answer = list(set(answer))
    answer.sort()
    return answer

# %%
from itertools import combinations as c
def solution(numbers):
    answer = []
    answer = sorted(set(sum(i) for i in c(numbers,2)))
    return answer
