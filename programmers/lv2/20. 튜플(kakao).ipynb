# %%
def solution(s):
    s = s.replace('{','')
    s = s.replace('}','')
    s = sorted(list(map(int,s.split(','))))
    answer = [0]*len(set(s))
    for i in set(s):
        answer[len(set(s)) - s.count(i)] = i
    return answer

# %%
solution("{{4,2,3},{3},{2,3,4,1},{2,3}}")
# Out:
# [3, 2, 4, 1]
