# %%
def solution(s):
    cnt = 0
    x = 0
    while True:
        cnt += s.count('0')
        s = s.replace('0','')
        s = format(len(s), 'b')
        x += 1
        if s == '1':
            break
    return [x, cnt]
