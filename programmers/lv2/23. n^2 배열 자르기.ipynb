# %%
def solution(n, left, right):
    answer = []
    for i in range(left, right+1):
        if i // n < i % n:
            answer.append(1 + (i % n))
        else:
            answer.append(1 + (i // n))
    return answer

# %%
solution(3,2,5)
# Out:
# [3, 2, 2, 3]
