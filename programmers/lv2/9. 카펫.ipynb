# %%
def solution(brown, yellow):
    answer = []
    for i in range(1, brown):
        for j in range(1, brown):
            if i >= j and i * 2 + ((j-2)*2) == brown and i * j == brown+yellow:
                return [i,j]
