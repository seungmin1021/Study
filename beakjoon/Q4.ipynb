# %%
st = input()
result = int(st[0])
for i in st[1:]:
    if i == '0' or i == '1' or result == 0 or result == 1:
        result += int(i)
    else:
        result *= int(i)
print(result)
# Out:
# 02984
# 576
