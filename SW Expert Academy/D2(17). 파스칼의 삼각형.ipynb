# %%
t = int(input())
for i in range(t):
    n = int(input())
    print('#{}'.format(i+1))
    for j in range(n):
        for k in range(j+1):
            if j > 1 and k > 0 and k < j:
                print(j,end=' ')
            else:
                print(1,end=' ')
        print()
# Out:
# 1
# 4
# #1
# 1
# 1 1
# 1 2 1
# 1 3 3 1
