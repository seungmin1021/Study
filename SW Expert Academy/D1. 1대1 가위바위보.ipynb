# %%
a, b = map(int,input().split())
if a > b:
    if a == 3 and b == 1:
        print('B')
    else:
        print('A')
if a < b:
    if b == 3 and a == 1:
        print('A')
    else:
        print('B')
# Out:
# 1 3
# A
