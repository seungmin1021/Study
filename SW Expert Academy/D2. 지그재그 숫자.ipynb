# %%
sum = 0
n = int(input())
for i in range(n):
    a = int(input())
    for j in range(1,a+1):
        if j % 2 == 0:
            sum -= j
        else:
            sum += j
    print('#{} {}'.format(i+1,sum))
    sum = 0
# Out:
# 2
# 5
# #1 3
# 6
# #2 -3
