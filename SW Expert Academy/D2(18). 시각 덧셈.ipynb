# %%
t = int(input())
for i in range(t):
    h1, m1, h2, m2 = map(int,input().split())
    h = h1+h2
    m = m1+m2
    if m >=60:
        h = h+m//60
        m = m%60
    if h >=13:
        h = h % 12
    if h == 0:
        h = 12
    print('#{} {} {}'.format(i+1, h, m))
