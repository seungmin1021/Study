# %%
t = int(input())
for i in range(t):
    n, k = map(int,input().split())
    a = [j for j in range(1,n+1)]
    b = list(map(int,input().split()))
    for j in b:
        a.remove(j)
    print('#{}'.format(i+1),end=' ')
    for j in a:
        print(j,end=' ')
    print()
