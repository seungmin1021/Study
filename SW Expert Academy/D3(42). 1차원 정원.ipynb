# %%
t = int(input())
for i in range(t):
    n, d = map(int,input().split())
    x = d*2+1
    if n % x == 0:
        print('#{} {}'.format(i+1, n//d))
    else:
        print('#{} {}'.format(i+1, n//d +1))
