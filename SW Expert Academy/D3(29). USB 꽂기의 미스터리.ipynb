# %%
t = int(input())
for i in range(t):
    p, q = map(float, input().split())
    s1 = (1-p)*q
    s2 = p*(1-q)*q
    print('#{} {}'.format(i+1, 'YES' if s1 < s2 else 'NO'))
# Out:
# 1
# 0.8 0.5
# #1 YES
