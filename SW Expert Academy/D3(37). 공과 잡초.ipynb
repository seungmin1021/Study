# %%
t = int(input())
for i in range(t):
    s = input()
    cnt = 0
    for j in range(len(s)):
        if s[j] == '(' and s[j+1] != ')':
            cnt += 1
        elif s[j] == ')':
            cnt += 1
    print('#{} {}'.format(i+1, cnt))
