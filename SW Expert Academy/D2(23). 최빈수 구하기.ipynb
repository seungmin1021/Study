# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = list(map(int,input().split()))
    cur = 0
    for j in range(101):
        if a.count(j) >= a.count(cur):
            cur = j
    print('#{} {}'.format(i+1, cur))
