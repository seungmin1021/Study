# %%
t = int(input())
for i in range(t):
    s = ''.join(sorted(list(input())))
    a = set(list(s))
    for j in a:
        s = s.replace(j*2,'')
    if s == '':
        print('#{} Good'.format(i+1))
    else:
        a = sorted(list(s))
        print('#{} {}'.format(i+1, ''.join(a)))
