# %%
t = int(input())
for i in range(t):
    a = list(map(int,input().split()))
    sum = 0
    for j in a:
        if j < 40:
            sum += 40
        else:
            sum += j
    print('#{} {}'.format(i+1, int(sum/len(a))))
# Out:
# 1
# 10 65 100 30 95
# #1 68.0
