# %%
t = int(input())
for i in range(t):
    a = input()
    b = '0'
    cnt = 0
    for j in range(len(a)):
        if a[j] != b:
            b = a[j]
            cnt += 1
    print('#{} {}'.format(i+1,cnt))
