# %%
t = int(input())
a = [31,29,31,30,31,30,31,31,30,31,30,31]
b = {0:3, 1:4, 2:5, 3:6, 4:0, 5:1, 6:2}
for i in range(t):
    m, d = map(int,input().split())
    s = 0
    for j in range(m-1):
        s += a[j]
    s += d
    print('#{} {}'.format(i+1, b[s%7]))
