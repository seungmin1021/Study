# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = list(map(int,input().split()))
    cnt = 0
    for j in range(1,len(a)-1):
        if a[j] != max(a[j-1],a[j],a[j+1]) and a[j] != min(a[j-1],a[j],a[j+1]):
            cnt += 1
    print('#{} {}'.format(i+1, cnt))
