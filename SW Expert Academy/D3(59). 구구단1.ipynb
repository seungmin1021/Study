# %%
def mul(n):
    for i in range(1,10):
        for j in range(1,10):
            if i * j == n:
                return 'Yes'
    return 'No'
for t in range(int(input())):
    n = int(input())
    s = mul(n)
    print('#{} {}'.format(t+1,s))
