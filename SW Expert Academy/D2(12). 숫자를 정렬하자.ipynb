# %%
t = int(input())
for i in range(t):
    n = int(input())
    nums = sorted(list(map(int,input().split())))
    print('#{}'.format(i+1),end=' ')
    print(*nums)
# Out:
# 1
# 5
# 1 4 7 8 0
# #1 0 1 4 7 8
