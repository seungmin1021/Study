# %%
n = int(input())
s = ['3','6','9']
for i in range(1,n+1):
    if 29 < i < 40 or 59 < i < 70 or 89 < i < 100:
        if '3' in str(i)[1] or '6' in str(i)[1] or '9' in str(i)[1]:
            print('--',end=' ')
        else:
            print('-',end=' ')
    else:
        if '3' in str(i) or '6' in str(i) or '9' in str(i):
            print('-',end=' ')
        else:
            print(i,end=' ')
# Out:
# 100
# 1 2 - 4 5 - 7 8 - 10 11 12 - 14 15 - 17 18 - 20 21 22 - 24 25 - 27 28 - - - - -- - - -- - - -- 40 41 42 - 44 45 - 47 48 - 50 51 52 - 54 55 - 57 58 - - - - -- - - -- - - -- 70 71 72 - 74 75 - 77 78 - 80 81 82 - 84 85 - 87 88 - - - - -- - - -- - - -- 100
