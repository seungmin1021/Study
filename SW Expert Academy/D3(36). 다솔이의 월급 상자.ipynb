# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = [list(map(float,input().split())) for _ in range(n)]
    sum = 0
    for j in a:
        sum += j[0] * j[1]
    print('#{} {:.7f}'.format(i+1, sum))
# Out:
# 1
# 2
# 0.3 100
# 0.7 4
# 32.8000000
