# %%
t = int(input())
dic = {"ZRO":0, "ONE":1, "TWO":2, "THR":3, "FOR":4, "FIV":5, "SIX":6, "SVN":7, "EGT":8, "NIN":9}
for i in range(t):
    s, n = map(str,input().split())
    a = list(map(str,input().split()))
    a.sort(key = lambda x : dic[x])
    print(s, ' '.join(a),sep=' ')
# Out:
# 1
# #1 1
# SVN FOR ZRO NIN FOR EGT EGT TWO FOR FIV FIV ONE
# #1 ZRO ONE TWO FOR FOR FOR FIV FIV SVN EGT EGT NIN
