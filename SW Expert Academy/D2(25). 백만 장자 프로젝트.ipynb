# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = list(map(int,input().split()))
    s = 0
    cur = a[-1]
    for j in range(n-1,-1,-1):
        if a[j] > cur:
            cur = a[j]
        else:
            s += cur - a[j]
    print('#{} {}'.format(i+1,s))
# Out:
# 1
# 5
# 1 1 3 1 2
# #1 5
