# %%
for i in range(10):
    n = int(input())
    a = list(map(int,input().split()))
    for j in range(n):
        a[a.index(max(a))] -= 1
        a[a.index(min(a))] += 1
    print('#{} {}'.format(i+1, max(a)-min(a)))
