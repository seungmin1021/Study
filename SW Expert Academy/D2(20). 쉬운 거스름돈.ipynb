# %%
t = int(input())
m = [50000,10000,5000,1000,500,100,50,10]
for j in range(t):
    result = []
    n = int(input())
    for i in m:
        result.append(n//i)
        n = n-(i * (n//i))
    print('#{}'.format(j+1))
    print(*result)
# Out:
# 2
# 32850
# #1
# 0 3 0 2 1 3 1 0
# 160
# #2
# 0 0 0 0 0 1 1 1
