# %%
t = int(input())
for i in range(t):
    a, b = map(int,input().split())
    if a+b>=24:
        print('#{} {}'.format(i+1,(a+b)%24))
    else:
        print('#{} {}'.format(i+1,(a+b)))
# Out:
# 1
# 7 17
# #1 0
