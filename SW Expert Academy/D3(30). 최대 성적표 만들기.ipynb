# %%
t = int(input())
for i in range(t):
    n, k = map(int,input().split())
    a = sorted(list(map(int,input().split())),reverse = True)
    sum = 0
    for j in range(k):
        sum += a[j]
    print('#{} {}'.format(i+1, sum))
# Out:
# 1
# 3 2
# 100 70 90
# #1 190
