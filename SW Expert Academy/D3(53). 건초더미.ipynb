# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = [int(input()) for _ in range(n)]
    avg = sum(a)/len(a)
    cnt = 0
    a.sort(reverse = True)
    for j in a:
        if j <= avg:
            break
        cnt += j - avg
    print('#{} {}'.format(i+1, cnt))
