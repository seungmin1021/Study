# %%
t = int(input())
for i in range(t):
    l, u, x = map(int,input().split())
    if x > u:
        print('#{} {}'.format(i+1, -1))
    elif l <=  x <= u:
        print('#{} {}'.format(i+1, 0))
    elif x < l:
        print('#{} {}'.format(i+1, l-x))
# Out:
# 1
# 300 400 240
# #1 60
