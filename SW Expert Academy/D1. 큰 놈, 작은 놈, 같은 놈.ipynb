# %%
n = int(input())
for i in range(n):
    a, b = map(int,input().split())
    if a > b:
        print('#{} {}'.format(i+1,'>'))
    elif a == b:
        print('#{} {}'.format(i+1,'='))
    elif a < b:
        print('#{} {}'.format(i+1,'<'))
# Out:
# 3
# 3 8
# #1 <
# 7 7
# #2 =
# 369 123
# #3 >
