# %%
from itertools import combinations as c
t = int(input())
for i in range(t):
    a = list(map(int,input().split()))
    b = list(set(list(sum(i) for i in c(a,3))))
    b.sort(reverse = True)
    print(b)
    print('#{} {}'.format(i+1, b[4]))
# Out:
# 1
# 1 2 3 4 5 6 7
# [18, 17, 16, 15, 14, 13, 12, 11, 10, 9, 8, 7, 6]
# #1 14
