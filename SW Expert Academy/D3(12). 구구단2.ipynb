# %%
t = int(input())
for i in range(t):
    a = list(map(int,input().split()))
    if any(j > 9 for j in a):
        print('#{} {}'.format(i+1, -1))
    else:
        print('#{} {}'.format(i+1, a[0]*a[1]))
# Out:
# 2
# 2 5
# #1 10
# 5 10
# #2 -1
