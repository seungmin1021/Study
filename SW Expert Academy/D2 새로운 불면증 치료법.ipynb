# %%
n = int(input())
for i in range(n):
    ans = [0]*10
    a = int(input())
    k = 1
    while True:
        for j in str(a*k):
            ans[int(j)] += 1
        k += 1
        if 0 not in ans:
            break
    print('#{} {}'.format(i+1,(k-1)*a))
# Out:
# 5
# 1
# #1 10
# 2
# #2 90
# 11
# #3 110
# 1295
# #4 6475
# 1692
# #5 5076
