# %%
t = int(input())
for i in range(t):
    n = int(input())
    a = list(map(int,input().split()))
    avg = sum(a)/len(a)
    s = 0
    for j in a:
        if avg >= j:
            s += 1
    print('#{} {}'.format(i+1, s))
