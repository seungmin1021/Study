# %%
t = int(input())
for i in range(t):
    a = sorted(list(map(int,input().split())))
    print('#{} {}'.format(i+1,(a[0]*2)+(a[-1]*2)-sum(a)))
# Out:
# 3
# 1 1 2
# #1 2
# 4 3 4
# #2 3
# 5 5 5
# #3 5
