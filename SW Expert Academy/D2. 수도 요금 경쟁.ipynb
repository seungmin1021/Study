# %%
n = int(input())
for i in range(n):
    p,q,r,s,w = map(int,input().split())
    a = p * w
    if r >= w:
        b = q
    else:
        b = q + ((w - r) * s)
    print('#{} {}'.format(i+1,b if a > b else a))
# Out:
# 2
# 9 100 20 3 10
# #1 90
# 8 300 100 10 250
# #2 1800
