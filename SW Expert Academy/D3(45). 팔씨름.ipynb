# %%
t = int(input())
for i in range(t):
    s = input()
    cnt = 0
    for j in s:
        if j == 'o':
            cnt += 1
    if cnt+(15-len(s)) >= 8:
        print('#{} YES'.format(i+1))
    else:
        print('#{} NO'.format(i+1))
