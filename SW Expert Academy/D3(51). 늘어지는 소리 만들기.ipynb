# %%
t = int(input())
for i in range(t):
    s = list(input())
    n = int(input())
    a = sorted(list(map(int,input().split())),reverse = True)
    for j in a:
        s.insert(j,'-')
    print('#{} {}'.format(i+1, ''.join(s)))
# Out:
# 1
# wow
# 3
# 2 3 2
# #1 wo--w-
