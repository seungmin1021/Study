# %%
t = int(input())
for i in range(t):
    a = b = 1
    command = input()
    for j in command:
        if j == 'L':
            b +=a
        else:
            a += b
    print('#{} {} {}'.format(i+1, a, b))
